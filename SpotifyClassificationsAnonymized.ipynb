# %% [markdown]
# Rickord, Jake JJ<br>
# Project 3: Spotify Song Classifications<br>

# %% [markdown]
# Import needed packages

# %%
import os
import pandas as pd
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support as score

# %% [markdown]
# Authenticate requests

# %%
scope = "user-library-read"

auth_manager = SpotifyClientCredentials(client_id='######', client_secret='#########')
sp = spotipy.Spotify(client_credentials_manager = auth_manager)

# %% [markdown]
# Extract track listings from liked playlist

# %%
track_uris = []
playlist_uri='3gfQ9CScIyMxMZwphYM4cZ'
pl_pull = sp.playlist_tracks(playlist_uri)['items']
for track in pl_pull:
    track_uris.append(track['track']['uri'])

# %%
print(track_uris)
# Out:
# ['spotify:track:36lV4io8Gc69fDinNaazAg', 'spotify:track:0YOOXnCJihgyluizqhAcrz', 'spotify:track:49YQ9Mq8CKelQsmjdNiICu', 'spotify:track:1vXHRgrkWnCMab8dhVPh0f', 'spotify:track:3h5AZDf5z7D18plaLtHTfi', 'spotify:track:1tQGRq2WOBXjL3JWdWMONg', 'spotify:track:3UCnS94uOqgvTmHohbgH9W', 'spotify:track:1WSEWiuB7KeEchBhvRb7qX', 'spotify:track:4z5kF7eIQhc6cvdb2MxEDD', 'spotify:track:1kStecVGAvK2RLhf0S9ywc', 'spotify:track:5tN0LIuQDapSFedlYJuG0k', 'spotify:track:3R6yNicsZrWF8ybl02imcB', 'spotify:track:0YnbCBn2UdoM5Y1l6Am5EY', 'spotify:track:4a2uqVlpRChHj32EjJLu7G', 'spotify:track:7rwKNqgVO0OfdOLNSKfYR4', 'spotify:track:4Oz6xl8qhJTdjYZeT98V4m', 'spotify:track:48nZLOpJOINkICPWpUuhaN', 'spotify:track:6P7kZB7hSJFyaYJcu3cYQJ', 'spotify:track:0Ld3o5VR3A5c8Je92xFG4e', 'spotify:track:3BCsNM2w6HcCbrVWlhjTpk', 'spotify:track:3Ozx6IrGdoQyAworJzvBDE', 'spotify:track:3t5UYY2uXE6CIEd6FYXrho', 'spotify:track:5Os2lSlPvvc40Wmun45Tz8', 'spotify:track:62EcdBCqjB62CxnhgBkkJT', 'spotify:track:5XpJVr7FpYkZrgPCHbFF4E', 'spotify:track:0H7ROR8cZTsh6YUgnlqjM2', 'spotify:track:1tScrLohhBQSwuHRk6wkkV', 'spotify:track:2gE58DQyqgsvsK87SWUN62', 'spotify:track:3jSc6a7N6L9RhAhxjh9VQP', 'spotify:track:1nMlHxWuPc5P9Y5nGvenlj', 'spotify:track:2fSIF8CJhoc9CJhF9vJDXp', 'spotify:track:6qfg00bGlM1dQJwq08lZGi', 'spotify:track:2c62Xf5Po1YSa1N6LOjPHy', 'spotify:track:1q1j4J77FDgq3fqnFCLSvi', 'spotify:track:76r1FmtRgDKkiZ6Uru459R', 'spotify:track:6AYFKOPbmd12rUP5DalRwB', 'spotify:track:63XEl1dXbErfNDia83Ao3B', 'spotify:track:6255IIBwKySv6RYrOeHfQh', 'spotify:track:5AeoHJUx0PJXAzN425xryh', 'spotify:track:2bBSKXRsX0MDrMolVom4jy', 'spotify:track:78NnAw2qrlMrsedXLWLsYj', 'spotify:track:2RmH5VLkfdILc6wTK1LWkH', 'spotify:track:2wDuq
# %%
print(len(track_uris))
# Out:
# 100

# %% [markdown]
# Looks like we only grabbed the first 100, let's try to grab the rest of the entries as well, looks like from documentation on spotipy we'll need to continue with other pages of return.

# %%
track_uris = []
playlist_uri='3gfQ9CScIyMxMZwphYM4cZ'
#grabs return
pl_pull = sp.playlist_tracks(playlist_uri)
#page 1 of return
track_list = pl_pull['items']
#grabs all pages, adds them to track_list
while pl_pull['next']:
    pl_pull = sp.next(pl_pull)
    track_list.extend(pl_pull['items'])
#just grab the uris from it
for track in track_list:
    track_uris.append(track['track']['uri'])

# %%
print(len(track_uris))
# Out:
# 568

# %% [markdown]
# Now it looks like we've grabbed the full playlist. Let's grab their sound details now for each track, and add these details into a dataframe.

# %% [markdown]
# First let's set up the dataframe with the style we'd like it in

# %%
track_features = list(sp.audio_features(track_uris[0])[0].keys())
track_features.insert(0, 'track_uri')
track_features.append('Liked?')
df = pd.DataFrame(columns = track_features)
print(df)
# Out:
# Empty DataFrame
# Columns: [track_uri, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature, Liked?]
# Index: []

# %% [markdown]
# Looks great, now let's add our songs to it

# %%
for track in track_uris:
    i_tf = list(sp.audio_features(track)[0].values())
    i_tf.insert(0, track[track.index('track:')+len('track:'):])
    i_tf.append(1)
    df.loc[len(df)] = i_tf
print(df)
# Out:
#                   track_uri  danceability  energy  key  loudness  mode  \
# 0    36lV4io8Gc69fDinNaazAg         0.591   0.411    9    -7.496     1
# 1    0YOOXnCJihgyluizqhAcrz         0.495   0.434    2    -8.079     1
# 2    49YQ9Mq8CKelQsmjdNiICu         0.470   0.220    3   -11.727     1
# 3    1vXHRgrkWnCMab8dhVPh0f         0.490   0.180    7   -13.332     1
# 4    3h5AZDf5z7D18plaLtHTfi         0.632   0.254    3   -10.898     1
# ..                      ...           ...     ...  ...       ...   ...
# 563  1UVaHJQCmYxBK4XpYnYazU         0.519   0.691    9   -10.254     0
# 564  4ma2AbPdsy5ijCyJn16mAv         0.515   0.418    2   -11.794     1
# 565  5i4cie6F2AD20KiZ3XxUTq         0.371   0.640    9    -9.154     0
# 566  3e9dlCDa68YOOJ5kFSiEdp         0.524   0.733    0    -7.390     1
# 567  77R5bi9hfAUKZmu6tjOcxg         0.470   0.133   11   -13.678     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0299        0.7130          0.000000    0.1150   0.4540  153.616
# 1         0.0313        0.8970          0.000393    0.1090   0.2300   82.160
# 2         0.0430        0.8660          0.000001    0.1130   0.3490  156.109
# 3         0.0357        0.8980          0.000044    0.1090   0.1030  152.386
# 4         0.0338        0.9220          0.000091    0.1300   0.2320  106.026
# ..           ...           ...               ...       ...      ...      ...
# 563       0.0354        0.1390          0.156000    0.1160   0.6110  157.903
# 564       0.0361        0.3340          0.159000    0.1070   0.1440  143.969
# 565       0.0462        0.0126          0.342000    0.0939   0.2020  180.053
# 566       0.0404        0.0055          0.006540    0.0860   0.5180  144.037
# 567       0.0394        0.8250          0.000002    0.1190   0.0463   67.609
#
#                type                      id  \
# 0    audio_features  36lV4io8Gc69fDinNaazAg
# 1    audio_features  0YOOXnCJihgyluizqhAcrz
# 2    audio_features  49YQ9Mq8CKelQsmjdNiICu
# 3    audio_features  1vXHRgrkWnCMab8dhVPh0f
# 4    audio_features  3h5AZDf5z7D18plaLtHTfi
# ..              ...                     ...
# 563  audio_features  1UVaHJQCmYxBK4XpYnYazU
# 564  audio_features  4ma2AbPdsy5ijCyJn16mAv
# 565  audio_features  5i4cie6F2AD20KiZ3XxUTq
# 566  audio_features  3e9dlCDa68YOOJ5kFSiEdp
# 567  audio_features  77R5bi9hfAUKZmu6tjOcxg
#
#                                       uri  \
# 0    spotify:track:36lV4io8Gc69fDinNaazAg
# 1    spotify:track:0YOOXnCJihgyluizqhAcrz
# 2    spotify:track:49YQ9Mq8CKelQsmjdNiICu
# 3    spotify:track:1vXHRgrkWnCMab8dhVPh0f
# 4    spotify:track:3h5AZDf5z7D18plaLtHTfi
# ..                                    ...
# 563  spotify:track:1UVaHJQCmYxBK4XpYnYazU
# 564  spotify:track:4ma2AbPdsy5ijCyJn16mAv
# 565  spotify:track:5i4cie6F2AD20KiZ3XxUTq
# 566  spotify:track:3e9dlCDa68YOOJ5kFSiEdp
# 567  spotify:track:77R5bi9hfAUKZmu6tjOcxg
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/36lV4io8Gc69...
# 1    https://api.spotify.com/v1/tracks/0YOOXnCJihgy...
# 2    https://api.spotify.com/v1/tracks/49YQ9Mq8CKel...
# 3    https://api.spotify.com/v1/tracks/1vXHRgrkWnCM...
# 4    https://api.spotify.com/v1/tracks/3h5AZDf5z7D1...
# ..                                                 ...
# 563  https://api.spotify.com/v1/tracks/1UVaHJQCmYxB...
# 564  https://api.spotify.com/v1/tracks/4ma2AbPdsy5i...
# 565  https://api.spotify.com/v1/tracks/5i4cie6F2AD2...
# 566  https://api.spotify.com/v1/tracks/3e9dlCDa68YO...
# 567  https://api.spotify.com/v1/tracks/77R5bi9hfAUK...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/36lV...       269680
# 1    https://api.spotify.com/v1/audio-analysis/0YOO...       180400
# 2    https://api.spotify.com/v1/audio-analysis/49YQ...       320520
# 3    https://api.spotify.com/v1/audio-analysis/1vXH...       248173
# 4    https://api.spotify.com/v1/audio-analysis/3h5A...       192427
# ..                                                 ...          ...
# 563  https://api.spotify.com/v1/audio-analysis/1UVa...       278223
# 564  https://api.spotify.com/v1/audio-analysis/4ma2...       236884
# 565  https://api.spotify.com/v1/audio-analysis/5i4c...       248524
# 566  https://api.spotify.com/v1/audio-analysis/3e9d...       218628
# 567  https://api.spotify.com/v1/audio-analysis/77R5...       169904
#
#      time_signature  Liked?
# 0                 4       1
# 1                 4       1
# 2                 3       1
# 3                 4       1
# 4                 4       1
# ..              ...     ...
# 563               4       1
# 564               4       1
# 565               4       1
# 566               4       1
# 567               4       1
#
# [568 rows x 20 columns]

# %% [markdown]
# Looking spectacular. Now we have our dataset for songs we like. Now let's grab a dataset of songs we dislike. We've sampled some here in a collection: "6kT6nn9Vd1e52XRG7OS2IE"

# %%
bad_track_uris = []
bad_playlist_uri='6kT6nn9Vd1e52XRG7OS2IE'
bad_pl_pull = sp.playlist_tracks(bad_playlist_uri)['items']
for track in bad_pl_pull:
    bad_track_uris.append(track['track']['uri'])

# %% [markdown]
# And let's add these to that dataframe

# %%
for track in bad_track_uris:
    i_tf = list(sp.audio_features(track)[0].values())
    i_tf.insert(0, track[track.index('track:')+len('track:'):])
    i_tf.append(0)
    df.loc[len(df)] = i_tf
print(df)
# Out:
#                   track_uri  danceability  energy  key  loudness  mode  \
# 0    36lV4io8Gc69fDinNaazAg         0.591   0.411    9    -7.496     1
# 1    0YOOXnCJihgyluizqhAcrz         0.495   0.434    2    -8.079     1
# 2    49YQ9Mq8CKelQsmjdNiICu         0.470   0.220    3   -11.727     1
# 3    1vXHRgrkWnCMab8dhVPh0f         0.490   0.180    7   -13.332     1
# 4    3h5AZDf5z7D18plaLtHTfi         0.632   0.254    3   -10.898     1
# ..                      ...           ...     ...  ...       ...   ...
# 613  1LJYn86ysceH708AIkw0VZ         0.975   0.482    9    -7.940     1
# 614  7FERnkDYqD9D9DJdNjQlnf         0.761   0.246    0   -11.676     1
# 615  4F0flTfcEU2ZcStYhJsaRy         0.862   0.717    9    -7.158     1
# 616  15hJmqqEtASVXl6sM7i4UF         0.615   0.600   10    -5.620     1
# 617  0lTqQTHcYb0RzGa5STjVrf         0.821   0.714    2    -5.977     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0299       0.71300          0.000000    0.1150   0.4540  153.616
# 1         0.0313       0.89700          0.000393    0.1090   0.2300   82.160
# 2         0.0430       0.86600          0.000001    0.1130   0.3490  156.109
# 3         0.0357       0.89800          0.000044    0.1090   0.1030  152.386
# 4         0.0338       0.92200          0.000091    0.1300   0.2320  106.026
# ..           ...           ...               ...       ...      ...      ...
# 613       0.2460       0.00716          0.000000    0.0596   0.7370  125.953
# 614       0.2450       0.13200          0.000000    0.0800   0.2260  130.012
# 615       0.4600       0.16600          0.000000    0.1970   0.7750   77.620
# 616       0.2700       0.10700          0.000002    0.2830   0.0661  130.027
# 617       0.3740       0.10900          0.000000    0.2980   0.6650   81.393
#
#                type                      id  \
# 0    audio_features  36lV4io8Gc69fDinNaazAg
# 1    audio_features  0YOOXnCJihgyluizqhAcrz
# 2    audio_features  49YQ9Mq8CKelQsmjdNiICu
# 3    audio_features  1vXHRgrkWnCMab8dhVPh0f
# 4    audio_features  3h5AZDf5z7D18plaLtHTfi
# ..              ...                     ...
# 613  audio_features  1LJYn86ysceH708AIkw0VZ
# 614  audio_features  7FERnkDYqD9D9DJdNjQlnf
# 615  audio_features  4F0flTfcEU2ZcStYhJsaRy
# 616  audio_features  15hJmqqEtASVXl6sM7i4UF
# 617  audio_features  0lTqQTHcYb0RzGa5STjVrf
#
#                                       uri  \
# 0    spotify:track:36lV4io8Gc69fDinNaazAg
# 1    spotify:track:0YOOXnCJihgyluizqhAcrz
# 2    spotify:track:49YQ9Mq8CKelQsmjdNiICu
# 3    spotify:track:1vXHRgrkWnCMab8dhVPh0f
# 4    spotify:track:3h5AZDf5z7D18plaLtHTfi
# ..                                    ...
# 613  spotify:track:1LJYn86ysceH708AIkw0VZ
# 614  spotify:track:7FERnkDYqD9D9DJdNjQlnf
# 615  spotify:track:4F0flTfcEU2ZcStYhJsaRy
# 616  spotify:track:15hJmqqEtASVXl6sM7i4UF
# 617  spotify:track:0lTqQTHcYb0RzGa5STjVrf
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/36lV4io8Gc69...
# 1    https://api.spotify.com/v1/tracks/0YOOXnCJihgy...
# 2    https://api.spotify.com/v1/tracks/49YQ9Mq8CKel...
# 3    https://api.spotify.com/v1/tracks/1vXHRgrkWnCM...
# 4    https://api.spotify.com/v1/tracks/3h5AZDf5z7D1...
# ..                                                 ...
# 613  https://api.spotify.com/v1/tracks/1LJYn86ysceH...
# 614  https://api.spotify.com/v1/tracks/7FERnkDYqD9D...
# 615  https://api.spotify.com/v1/tracks/4F0flTfcEU2Z...
# 616  https://api.spotify.com/v1/tracks/15hJmqqEtASV...
# 617  https://api.spotify.com/v1/tracks/0lTqQTHcYb0R...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/36lV...       269680
# 1    https://api.spotify.com/v1/audio-analysis/0YOO...       180400
# 2    https://api.spotify.com/v1/audio-analysis/49YQ...       320520
# 3    https://api.spotify.com/v1/audio-analysis/1vXH...       248173
# 4    https://api.spotify.com/v1/audio-analysis/3h5A...       192427
# ..                                                 ...          ...
# 613  https://api.spotify.com/v1/audio-analysis/1LJY...       146598
# 614  https://api.spotify.com/v1/audio-analysis/7FER...       132989
# 615  https://api.spotify.com/v1/audio-analysis/4F0f...       137806
# 616  https://api.spotify.com/v1/audio-analysis/15hJ...       270671
# 617  https://api.spotify.com/v1/audio-analysis/0lTq...       235583
#
#      time_signature  Liked?
# 0                 4       1
# 1                 4       1
# 2                 3       1
# 3                 4       1
# 4                 4       1
# ..              ...     ...
# 613               4       0
# 614               4       0
# 615               4       0
# 616               4       0
# 617               4       0
#
# [618 rows x 20 columns]

# %% [markdown]
# And now our dataset is complete with song info! Let's drop some of those auxilliary columns that aren't related to song information now.

# %%
df.columns
# Out:
# Index(['track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'Liked?'],
#       dtype='object')

# %%
df = df.drop(['id', 'type', 'uri', 'track_href', 'analysis_url'], axis=1)

# %%
print(df)
# Out:
#                   track_uri  danceability  energy  key  loudness  mode  \
# 0    36lV4io8Gc69fDinNaazAg         0.591   0.411    9    -7.496     1
# 1    0YOOXnCJihgyluizqhAcrz         0.495   0.434    2    -8.079     1
# 2    49YQ9Mq8CKelQsmjdNiICu         0.470   0.220    3   -11.727     1
# 3    1vXHRgrkWnCMab8dhVPh0f         0.490   0.180    7   -13.332     1
# 4    3h5AZDf5z7D18plaLtHTfi         0.632   0.254    3   -10.898     1
# ..                      ...           ...     ...  ...       ...   ...
# 613  1LJYn86ysceH708AIkw0VZ         0.975   0.482    9    -7.940     1
# 614  7FERnkDYqD9D9DJdNjQlnf         0.761   0.246    0   -11.676     1
# 615  4F0flTfcEU2ZcStYhJsaRy         0.862   0.717    9    -7.158     1
# 616  15hJmqqEtASVXl6sM7i4UF         0.615   0.600   10    -5.620     1
# 617  0lTqQTHcYb0RzGa5STjVrf         0.821   0.714    2    -5.977     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0299       0.71300          0.000000    0.1150   0.4540  153.616
# 1         0.0313       0.89700          0.000393    0.1090   0.2300   82.160
# 2         0.0430       0.86600          0.000001    0.1130   0.3490  156.109
# 3         0.0357       0.89800          0.000044    0.1090   0.1030  152.386
# 4         0.0338       0.92200          0.000091    0.1300   0.2320  106.026
# ..           ...           ...               ...       ...      ...      ...
# 613       0.2460       0.00716          0.000000    0.0596   0.7370  125.953
# 614       0.2450       0.13200          0.000000    0.0800   0.2260  130.012
# 615       0.4600       0.16600          0.000000    0.1970   0.7750   77.620
# 616       0.2700       0.10700          0.000002    0.2830   0.0661  130.027
# 617       0.3740       0.10900          0.000000    0.2980   0.6650   81.393
#
#      duration_ms  time_signature  Liked?
# 0         269680               4       1
# 1         180400               4       1
# 2         320520               3       1
# 3         248173               4       1
# 4         192427               4       1
# ..           ...             ...     ...
# 613       146598               4       0
# 614       132989               4       0
# 615       137806               4       0
# 616       270671               4       0
# 617       235583               4       0
#
# [618 rows x 15 columns]

# %% [markdown]
# Okay, now with our dataset all rev'd up, time to split it into training and test sets!

# %%
X = df.drop(['track_uri', 'Liked?'], axis=1)
y = df['Liked?']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)
print(X_train)
print(y_train)
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 89          0.575   0.765    9    -6.608     1       0.0345       0.00703
# 285         0.484   0.793    2    -6.797     1       0.2110       0.00069
# 310         0.625   0.715    7    -4.539     0       0.0942       0.04130
# 367         0.529   0.934    0    -4.808     1       0.0602       0.00153
# 46          0.410   0.233    0   -12.878     1       0.0286       0.83100
# ..            ...     ...  ...       ...   ...          ...           ...
# 277         0.674   0.204    5   -13.535     1       0.0384       0.88700
# 9           0.544   0.224    7   -14.410     1       0.0351       0.78100
# 359         0.397   0.903    2    -4.577     1       0.0457       0.00575
# 192         0.708   0.413    7   -10.856     1       0.1010       0.78300
# 559         0.499   0.160    7   -13.632     1       0.0362       0.89900
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 89           0.000000    0.3310   0.4070   98.037       205773               4
# 285          0.000281    0.1530   0.1060  184.618       247155               3
# 310          0.000000    0.1020   0.0377   84.794       205769               4
# 367          0.000005    0.1180   0.2820  127.962       241960               4
# 46           0.001050    0.1430   0.0556   52.042       129387               4
# ..                ...       ...      ...      ...          ...             ...
# 277          0.000209    0.0916   0.1310  120.294       260369               4
# 9            0.001400    0.1280   0.1890  105.347       128115               5
# 359          0.000002    0.3620   0.5560  151.551       201373               4
# 192          0.009830    0.1060   0.5380  163.862       187402               4
# 559          0.000038    0.1060   0.1030   77.090       248173               4
#
# [463 rows x 13 columns]
# 89     1
# 285    1
# 310    1
# 367    1
# 46     1
#       ..
# 277    1
# 9      1
# 359    1
# 192    1
# 559    1
# Name: Liked?, Length: 463, dtype: int64

# %% [markdown]
# Alrighty, now with that being broken up, we shall train our model and evaluate

# %% [markdown]
# Let's try out Logistic Regression, which will likely make the most sense considering our output of Liked? is binary, either yes or no.

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)

# %%
print(classification_report(y_test,predictions));
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.92      1.00      0.96       142
#
#     accuracy                           0.92       155
#    macro avg       0.46      0.50      0.48       155
# weighted avg       0.84      0.92      0.88       155

# %% [markdown]
# Interesting, it predicted that I don't dislike any songs. My tastes are decently diverse, but I think this is more likely due to the severe imbalance between the size of the liked songs playlist (about 550) and the size of the disliked songs playlist (about 60). Let's see if we can't use another algorithm to take into account some of this imbalance. The first one that comes to mind if the SVC model.

# %%
from sklearn.svm import SVC

# %%
svcmodel = SVC(kernel='linear', class_weight = {0:0.92, 1:0.08})
svcmodel.fit(X_train, y_train)
predictions = svcmodel.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.62      0.14        13
#            1       0.91      0.37      0.52       142
#
#     accuracy                           0.39       155
#    macro avg       0.50      0.49      0.33       155
# weighted avg       0.84      0.39      0.49       155

# %% [markdown]
# Looks like even with weightings inverse to their proportions our f-1 and accuracy score aren't great. Let's test a few different weights out and see what the ideal weighting is and the resulting f-1 score.

# %%
weight0 = 0
weight1 = 1
bestweight0 = 0
besweight1 = 1
bestf1 = 0
for asweight in np.arange(0, 1, 0.05):
    svcmodel = SVC(kernel='linear', class_weight = {0:weight0+asweight, 1:weight1-asweight})
    svcmodel.fit(X_train, y_train)
    predictions = svcmodel.predict(X_test)
    precision,recall,fscore,support=score(y_test,predictions,average='macro')
    if fscore>bestf1:
        bestf1=fscore
        bestweight0 = weight0+asweight
        bestweight1 = weight1-asweight

print(bestf1)
print(bestweight0)
print(bestweight1)
# Out:
# 0.4894598155467721
# 0.8500000000000001
# 0.1499999999999999

# %%
svcmodel = SVC(kernel = 'linear', class_weight = {0:0.85, 1:0.15})
svcmodel.fit(X_train, y_train)
predictions = svcmodel.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.15      0.11        13
#            1       0.92      0.84      0.88       142
#
#     accuracy                           0.78       155
#    macro avg       0.50      0.50      0.49       155
# weighted avg       0.85      0.78      0.81       155

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Looks like even with some balancing involved, we're still getting model outputs with best accuracy when disliked songs are simply excluded. Let's try taking a random sampling of our liked songs to try to even out the number of songs liked versus disliked.

# %%
bdf = pd.DataFrame(columns = df.columns)

# %% [markdown]
# Grab random 100 rows from liked playlist

# %%
bdf = df.loc[df['Liked?']==1].sample(n=50)
bdf
# Out:
#                   track_uri  danceability  energy  key  loudness  mode  \
# 104  6mPpHS9ocuKjsehu8NgD7r         0.430   0.501    9    -8.864     1
# 521  4urpFW2JCm486dHJmsQ8Ps         0.607   0.336    3   -11.854     1
# 526  7c6TRb4cvgHWVhTJDfRqth         0.598   0.898   10    -5.155     1
# 38   5AeoHJUx0PJXAzN425xryh         0.413   0.100    0   -16.349     1
# 469  0M3adYbGtyRHACP86dey1H         0.426   0.888    0    -3.720     0
# 153  3VGjFO89Sh53UjTRGJXWmi         0.529   0.497    2    -8.979     1
# 424  1Jj6MF0xDOMA3Ut2Z368Bx         0.724   0.436    0    -9.321     1
# 102  2Zgnaip1c876zmBhz9HifI         0.544   0.745    3    -3.401     1
# 248  2gA74HvN6NKFrhgzpd5oNE         0.645   0.486    0    -7.299     1
# 191  5zXNvJgCNNqmC262XJp8TW         0.663   0.649    9    -4.808     1
# 432  54ugrImfl3YTyfYEFFi4xq         0.467   0.966    7    -3.915     1
# 66   1kAvkf8WQgVGuwxvSqrVwQ         0.654   0.425    0    -9.432     1
# 330       0.0277      0.047100          0.000000    0.1120   0.0974  130.037
# 116       0.0668      0.575000          0.001590    0.0838   0.4850  120.219
# 33        0.0294      0.845000          0.677000    0.1870   0.0724  129.862
#
#      duration_ms  time_signature  Liked?
# 104       308373               4       1
# 521       198219               4       1
# 526       211933               4       1
# 38        184907               3       1
# 469       191520               4       1
# 153       285307               4       1
# 424       243067               4       1
# 102       195547               4       1
# 248       208187               4       1
# 191       201253               4       1
# 432       156227               3       1
# 66        196029               4       1
# 552       254160               4       1
# 493       199773               4       1
# 193       250280               4       1
# 135       208413               4       1
# 217       152640               4       1
# 383       220427               4       1
# 142       273880               4       1
# 292       178053               4       1
# 128       198101               4       1
# 399       258653               4       1
# 219       292143               4       1
# 483       215280               4       1
# 228       253869               4       1
# 561       221040               4       1
# 445       180560               4       1
# 12        137704               4       1
# 188       200401               4       1
# 291       212268               4       1
# 305       214493               4       1
# 186       213800               4       1
# 500       270920               4       1
# 453       244267               4       1
# 397       239053               4       1
# 339       208107               4       1
# 462       216013               4       1
# 382       277600               4       1
# 226       160120               3       1
# 459       229347               4       1
# 520       218027               4       1
# 384       267960               4       1
# 174       249520               3       1
# 474       289133               4       1
# 200       202194               4       1
# 341       297682               4       1
# 404       227267               4       1
# 330       282996               4       1
# 116       214570               4       1
# 33        159640               4       1

# %%
bdf = bdf.append(df.loc[df['Liked?']==0], ignore_index=True)
bdf
# Out:
#                  track_uri  danceability  energy  key  loudness  mode  \
# 0   6mPpHS9ocuKjsehu8NgD7r         0.430   0.501    9    -8.864     1
# 1   4urpFW2JCm486dHJmsQ8Ps         0.607   0.336    3   -11.854     1
# 2   7c6TRb4cvgHWVhTJDfRqth         0.598   0.898   10    -5.155     1
# 3   5AeoHJUx0PJXAzN425xryh         0.413   0.100    0   -16.349     1
# 4   0M3adYbGtyRHACP86dey1H         0.426   0.888    0    -3.720     0
# ..                     ...           ...     ...  ...       ...   ...
# 95  1LJYn86ysceH708AIkw0VZ         0.975   0.482    9    -7.940     1
# 96  7FERnkDYqD9D9DJdNjQlnf         0.761   0.246    0   -11.676     1
# 97  4F0flTfcEU2ZcStYhJsaRy         0.862   0.717    9    -7.158     1
# 98  15hJmqqEtASVXl6sM7i4UF         0.615   0.600   10    -5.620     1
# 99  0lTqQTHcYb0RzGa5STjVrf         0.821   0.714    2    -5.977     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0378      0.735000          0.002540    0.1110   0.4070  115.027
# 1        0.0284      0.603000          0.000008    0.1010   0.3370   86.042
# 2        0.1130      0.043300          0.000000    0.0976   0.4220   77.639
# 3        0.0332      0.784000          0.381000    0.0819   0.1860  110.696
# 4        0.0987      0.000455          0.000000    0.3060   0.3870  144.111
# ..          ...           ...               ...       ...      ...      ...
# 95       0.2460      0.007160          0.000000    0.0596   0.7370  125.953
# 96       0.2450      0.132000          0.000000    0.0800   0.2260  130.012
# 97       0.4600      0.166000          0.000000    0.1970   0.7750   77.620
# 98       0.2700      0.107000          0.000002    0.2830   0.0661  130.027
# 99       0.3740      0.109000          0.000000    0.2980   0.6650   81.393
#
#     duration_ms  time_signature  Liked?
# 0        308373               4       1
# 1        198219               4       1
# 2        211933               4       1
# 3        184907               3       1
# 4        191520               4       1
# ..          ...             ...     ...
# 95       146598               4       0
# 96       132989               4       0
# 97       137806               4       0
# 98       270671               4       0
# 99       235583               4       0
#
# [100 rows x 15 columns]

# %% [markdown]
# And now that we have a our balanced sample, let's proceed with our data split

# %%
bX = bdf.drop(['track_uri', 'Liked?'], axis=1)
by = bdf['Liked?']
bX_train,bX_test,by_train,by_test=train_test_split(bX,by,test_size=0.25,random_state=0)
print(X_train)
print(y_train)
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 89          0.575   0.765    9    -6.608     1       0.0345       0.00703
# 285         0.484   0.793    2    -6.797     1       0.2110       0.00069
# 310         0.625   0.715    7    -4.539     0       0.0942       0.04130
# 367         0.529   0.934    0    -4.808     1       0.0602       0.00153
# 46          0.410   0.233    0   -12.878     1       0.0286       0.83100
# ..            ...     ...  ...       ...   ...          ...           ...
# 277         0.674   0.204    5   -13.535     1       0.0384       0.88700
# 9           0.544   0.224    7   -14.410     1       0.0351       0.78100
# 359         0.397   0.903    2    -4.577     1       0.0457       0.00575
# 192         0.708   0.413    7   -10.856     1       0.1010       0.78300
# 559         0.499   0.160    7   -13.632     1       0.0362       0.89900
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 89           0.000000    0.3310   0.4070   98.037       205773               4
# 285          0.000281    0.1530   0.1060  184.618       247155               3
# 310          0.000000    0.1020   0.0377   84.794       205769               4
# 367          0.000005    0.1180   0.2820  127.962       241960               4
# 46           0.001050    0.1430   0.0556   52.042       129387               4
# ..                ...       ...      ...      ...          ...             ...
# 277          0.000209    0.0916   0.1310  120.294       260369               4
# 9            0.001400    0.1280   0.1890  105.347       128115               5
# 359          0.000002    0.3620   0.5560  151.551       201373               4
# 192          0.009830    0.1060   0.5380  163.862       187402               4
# 559          0.000038    0.1060   0.1030   77.090       248173               4
#
# [463 rows x 13 columns]
# 89     1
# 285    1
# 310    1
# 367    1
# 46     1
#       ..
# 277    1
# 9      1
# 359    1
# 192    1
# 559    1
# Name: Liked?, Length: 463, dtype: int64

# %% [markdown]
# And now our modelings to see if that performance is better.

# %%
blogmodel = LogisticRegression()
blogmodel.fit(bX_train,by_train)
bpredictions = blogmodel.predict(bX_test)
print(classification_report(by_test,bpredictions));
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.67      0.55        12
#            1       0.50      0.31      0.38        13
#
#     accuracy                           0.48        25
#    macro avg       0.49      0.49      0.47        25
# weighted avg       0.49      0.48      0.46        25

# %%
bsvcmodel = SVC(kernel='linear')
bsvcmodel.fit(bX_train, by_train)
bpredictions = bsvcmodel.predict(bX_test)
print(classification_report(by_test,bpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29        12
#            1       0.44      0.54      0.48        13
#
#     accuracy                           0.40        25
#    macro avg       0.39      0.39      0.38        25
# weighted avg       0.39      0.40      0.39        25

# %% [markdown]
# Now we have quite a few applications of classification models, which seems to be most accurate? The short answer is none of them are fantastic. However, the best of those shown depends on if FPs or FNs matter most. In our case neither really are all that great, we either listen to a song that we don't like or we miss songs we like that aren't recommended. I'd say as a result, the F-1 Score is the most important element of that evaluation. As such, we'd default to picking the modeling with the best F-1. This would be the SVC model with the weightings of 0.85 for our disliked and .15 for our liked songs to offset the imbalance between playlists.
